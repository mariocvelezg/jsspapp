# %%
import json
import requests

# %%
# These are the credentials defined in your Postman file
token_url = "http://177.253.137.210/api/Token"
username = "usr_prg"
password = "M1n1p37@2025"

# %%
def get_token():
    """
    Authenticates to the Elemental API and returns the access token string.
    """
    payload = {
        "grant_type": "password",
        "username": username,
        "password": password
    }

    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }

    response = requests.post(token_url, data=payload, headers=headers)

    # Basic error handling
    if response.status_code != 200:
        print("Error:", response.status_code, response.text)
        return None

    data = response.json()
    token = data.get("access_token")
    print("✅ Token obtained successfully!")
    return token

# %%
token = get_token()
# Out:
# ✅ Token obtained successfully!

# %%
headers = {
    "Authorization": f"Bearer {token}"
}

# %%
base_url = "http://177.253.137.210/api/api"
endpoint = f"{base_url}/vProductsDetails"

response = requests.get(endpoint, headers=headers)

# %%
print(response.status_code)
# Out:
# 200

# %%
with open("vProductsDetails.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

# %%
data
# Out:
# [{'id': 3634,
#   'productId': 'ENV703660',
#   'productName': 'ENVASE BALA 60 ML DE 8.3 GR GRIS 16196 SABIJERS',
#   'class': 3,
#   'className': 'boca 18',
#   'type': 17,
#   'typeName': '8.3 gr',
#   'family': 6,
#   'familyName': 'ENVASES',
#   'unit': 1,
#   'unitName': 'UNIDAD',
#   'unitAbbreviation': 'UND',
#   'comment': 'POLIETILENO TEREFTALATO (PET)',
#   'customer': None,
#   'customerName': None,
#   'customerId': None,
#   'weight': 8.3,
#   'description2': '',
#   'status': True,
#   'salePrice': 0.0,
#   'purchasePrice': 0.0,
#   'totalWeight': 8.3,
#   'minStock': None,
#   'high': None,
#   'width': None,
#   'perimeter': None,
#   'coveringId': None,
#   'descriptionCovering': None,
#   'coverLong': None,
#   'coverWidth': None,
#   'color': 23,
#   'colorName': 'GRIS ',
#   'caliber': None,
#   'colorCovering': None,
#   'coveringColorName': None,
#   'widthCovering': None,
#   'caliberCovering': None,
#   'grooveId': None,
#   'descriptionGroove': None,
# ...

# %%
with open("jobs.json", "w", encoding="utf-8") as f:
    json.dump(datos, f, indent=2, ensure_ascii=False)

# %%
json_path = r"C:\Users\marvelez\Dropbox\Planify\Proyectos\Elemental\Minipet\\"
with open(json_path+"response.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'workOrderId': '16524',
#   'productId': 'ENVINNTU3053',
#   'productName': 'ENVASE INNTU 30 ML DE 5.3 GR',
#   'productoDescription2': '',
#   'programedQty': 5076.0,
#   'optionRoute': '10',
#   'workUnitId': '8',
#   'conversionFactor': 2.0,
#   'standardCycle': 4.5,
#   'weight': 5.3,
#   'mold': '[INN30-218297] - INNTU 30 ML',
#   'familyName': 'ENVASES',
#   'workUnitCode': 'SOP09',
#   'workOrderNumber': None,
#   'workOrderPrimaryId': 18521,
#   'machineGroup': 2,
#   'id': '18521-3697-114',
#   'groupName': 'SOPLADO',
#   'isLastOperation': True,
#   'faseDescription': 'SOPLADO',
#   'packingQty': 1269.0,
#   'companyId': 1,
#   'staff': 1,
#   'comment': '',
#   'isGenericOrder': None},
#  {'workOrderId': '16634',
#   'productId': 'MPE10023353',
#   'productName': 'ENVASE FLORERO 33 ML DE 5.3 GR',
#   'productoDescription2': '',
#   'programedQty': 9000.0,
#   'optionRoute': '10',
#   'workUnitId': '5',
#   'conversionFactor': 4.0,
#   'standardCycle': 5.2,
# ...
